# %%
#9608 w18 41 Q5
class Cards:
    def __init__(self,num,shape):
        if (num >=0 or num <= 9) and (shape == "square" or shape == "triangle" or shape == "circle"):   
            self.__Number = int(num) # self.__Number is a integer
            self.__Shape = shape # self.__Shape is a string
        else:
            print("Invalid data")
        
        
    
    def getNumber(self):
        return self.__Number
    
    def getShape(self):
        return self.__Shape

# %%
#9608 w18 41 Q5
OneS = Cards(1,"square")

# %%
#9608 w18 41 Q5
def Compare(Card1, Card2):
    if Card1.Shape == Card2.Shape and Card1.Number == Card2.Number:
        print("SNAP")
        return -1
    else:
        if Card1.Number >= Card2.Number: return Card1.Number
        else: return Card2.Number

# %%
print(int(9.8))
# Out:
# 9
