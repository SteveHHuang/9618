# %%
#insertion sort
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

arr = [5, 2, 4, 6, 1, 3]
insertion_sort(arr)
print(arr)

# %%
# ALT version of insertion sort
# modified from 9608/42/M/J/18 Q3b
brr = [4,3,5,7,2]
def InsertionSort(arr):
    for i in range(1, len(arr)):
        HolePosition = i
        temp = arr[i]
        while (HolePosition > 0 and arr[HolePosition-1]>temp):
            arr[HolePosition] = arr[HolePosition-1]
            HolePosition -= 1
            # print(arr)     
        arr[HolePosition] = temp
        #print(arr)
    
    print(arr)
        
    
    
InsertionSort(brr)
# Out:
# [2, 3, 4, 5, 7]

# %%
# bubble sort
def bubble_sort(arr):
    j = len(arr)        
    while True:
        swap = False
        for k in range (j-1):
            if arr[k+1] < arr[k]:
                temp = arr[k+1]
                arr[k+1] = arr[k]
                arr[k] = temp
                swap = True
                
            print(crr)    
        j -= 1

        if swap == False or j <=0 :
            break 
crr = [5,9,3,11,2]
bubble_sort(crr)        
print(crr)

# %%
import random

# extension_selectionsort
def selectionsort(arr):
    for i in range(len(arr)):
        lowest = i 
        for j in range(i,len(arr)):
            if arr[j] < arr[lowest]:
                lowest = j
        arr[i],arr[lowest] = arr[lowest], arr[i]
            
            
arr = [random.randint(1,100) for k in range (10)]

print(arr)

selectionsort(arr)
print(arr)

# %%
x=10
y=15
x,y=y,x
print(x)
print(y)
