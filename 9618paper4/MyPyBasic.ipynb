# %%
a = '她说："你好！"'
print(a)

b = "It's a good day."
print(b)

text = '''这是第一行
这是第二行
这是第三行''' #三引号可以在多行文字上使用
print(text)
# Out:
# 她说："你好！"
# It's a good day.
# 这是第一行
# 这是第二行
# 这是第三行

# %%
MyList=[]
for i in range(0,5):
        MyList.append(0)


print(MyList)

# %%
M = int(input("input your raw mark:"))

count = 0
while  count <= 10 :
    
    if M >= 120:
        print("合格")
    else:
        print("不合格")
    count += 1

# %%
# variables, data types and expressions
# in python, variables can be used without declaration
# charachers can be used to a variable name 
# upper and lower letters, 0-9(number must not in the 1st place of the name)
intA = 10 # declare and initialise a variable, type of integer
intB = 20 
str1 = "abc"
print(type(intA))
print(type(str1))

# %%
# random func, for loop, while loop, range func

import random
wordNum = 0
for i in range (0, 10): #FOR I <- 1 TO 10 STEP 2
    r = random.randint(0, 10)
    print("i=", i, "\t"+"r=", r) # Alt: str(i) str(r), str(a) = NUM_TO_STR(a)
#      if r >= 5:
#          wordNum +=2
#      else:
#          wordNum +=1

# print(wordNum)

print("=================")

# while loop
i = 10
while i > 0:
    r = random.randint(0, 10)
    print("i=", i, "\t"+"r=", r)
    i -= 1
    
print("=================")

# %%
# input
# input a number, sum all non negative numbers, negative to exit
num = int(input("please input a number, negative to exit")) # input data is regarded as a type of string in python 
sum = 0
while num >= 0:
    sum += num
    num = int(input("please input a number, negative to exit"))
print("sum is", sum)

# %%
try:
    num = int(input("please input your salary"))

    if num >= 30000:
        print("high income")
    elif num >= 15000:
         print("medium income")
    else:
        print("just keep alive")
        
except:
    print("invalid input")
# Out:
# invalid input

# %%
a = 10
b = 20
c = 30
a >= b or b <= c
# Out:
# False

# %%
# define a func
import random

def randNum(lowerbound, upperbound):
    return random.randint(lowerbound, upperbound)
      
def randNum2():
    print(random.randint(1, 100))

# %%
# call a func
x = randNum(40,50)
y = randNum2()
# print(x)
print(y)   #In python, when t没有明确返回值的时候默认返回None
# Out:
# 92
# None

# %%
def test():
    return 1,2,3,4,5

z = test() 

print(z)
print(type(z))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
# 100以内加减法
import random

try:
    mark = 0
    StopPlaying = False

    def RandNumSummation(num1, num2):
            return num1 + num2

    while StopPlaying == False:
        num1 = random.randint(1,100)
        num2 = random.randint(1,100)
        ans = RandNumSummation(num1, num2)
        print("Calculate:", num1, "+", num2)
        correctAns = False
        while correctAns == False:
            response = int(input("input your answer:"))
            if response == ans:
                mark += 1
                correctAns = True
                print("correct")
                replay = int(input("want to play again?" + "press 1 to continue.\n"))
                if replay != 1:
                    StopPlaying = True
            else:
                print("incorrect, try again")

    print("You got", mark, "mark(s)")

except:
    print("invalid input, automatically stopped playing")
# Out:
# Calculate: 88 + 19
# correct
# Calculate: 78 + 17
# correct
# Calculate: 52 + 53
# correct
# Calculate: 23 + 2
# correct
# You got 4 mark(s)

# %%
#list(array) in py

#define an empty list
hybridlist = [] 

#define a list
intlist = [2,3,4,5]

print(type(hybridlist))
intlist[2] = 6
print(intlist)

# append add value in a list
hybridlist.append("echo")
hybridlist.append(99)
print(hybridlist)
# Out:
# <class 'list'>
# [2, 3, 6, 5]
# <built-in method count of list object at 0x0000013FCBD35E80>
# ['echo', 99]

# %%
count = 0
arr = []
swap = True

for i in range(1000):
    arr.append(random.randint(1,1000))
    
for num in arr:
    print(num, end=" ")
    count +=1
    if count %10 == 0:
        print()
    
    
while swap == True:    # bubble sort
    for j in range(999, 0, -1):
        for k in range (j):
            if arr[k+1] < arr[k]:
                temp = arr[k+1]
                arr[k+1] = arr[k]
                arr[k] = temp
            else:
                swap = False
        
print(arr)
# Out:
# 592 214 349 111 284 34 205 18 977 169
# 224 287 174 109 293 613 950 262 244 157
# 176 297 424 459 975 975 852 680 627 302
# 402 507 531 762 592 959 115 810 722 340
# 19 114 828 43 88 52 588 333 29 138
# 77 462 380 738 410 600 392 842 963 620
# 108 893 611 32 889 957 619 662 23 266
# 31 959 442 180 114 816 147 896 470 524
# 864 410 306 966 937 278 800 844 391 127
# 673 573 590 631 677 717 816 369 462 521
# 533 217 15 619 138 155 194 770 591 569
# 598 139 926 59 157 940 230 365 639 943
# 318 903 762 80 709 697 764 869 566 564
# 371 550 948 226 813 968 949 798 867 120
# 400 648 901 158 271 139 8 81 197 8
# 645 255 115 784 677 731 800 321 358 439
# 268 296 802 461 486 266 303 760 367 215
# 22 307 80 76 606 730 147 641 912 822
# 849 999 711 561 330 946 471 147 86 906
# 982 480 196 304 276 892 295 925 595 58
# 448 1000 772 651 43 159 755 379 484 382
# 187 559 595 614 908 275 642 577 610 17
# 186 113 302 542 487 529 934 208 287 296
# 189 653 513 572 452 61 935 662 415 640
# 108 630 624 429 421 707 350 769 669 576
# 876 933 785 417 890 441 232 52 515 651
# 574 673 351 554 747 879 489 797 549 923
# 669 212 664 710 429 756 386 913 887 30
# 212 384 422 310 929 410 274 666 58 559
# 668 440 597 364 286 173 769 518 366 114
# 86 663 894 946 472 78 145 954 985 90
# 23 762 312 609 256 487 79 842 424 596
# 334 528 9 698 673 693 951 241 102 150
# 855 998 902 157 538 721 54 101 111 757
# 838 554 334 518 654 227 268 741 510 692
# 948 956 223 32 194 684 861 699 345 95
# 47 233 921 806 666 896 371 93 634 563
# 908 768 426 616 969 587 63 425 801 298
# 700 19 726 382 965 945 954 704 369 350
# 265 311 175 598 93 958 190 119 155 82
# 480 723 555 842 807 346 135 587 139 914
# 69 618 115 252 306 205 733 583 450 799
# 767 881 887 993 568 406 867 154 3 870
# 809 388 963 436 633 807 933 427 29 749
# 531 549 660 43 530 406 178 478 993 375
# 556 97 719 47 20 235 353 255 490 595
# 309 608 331 926 810 284 849 436 350 808
# 618 284 60 752 658 948 509 49 814 4
# 464 31 572 967 152 872 654 290 808 662
# 880 539 732 863 172 964 15 683 848 703
# 889 137 307 811 8 933 767 439 517 30
# 838 466 149 243 390 845 129 103 473 521
# 865 751 869 558 473 800 379 666 98 700
# 732 728 81 973 208 755 60 650 450 776
# 595 527 694 770 488 42 807 220 285 131
# 459 123 284 196 146 153 54 654 104 755
# 221 433 370 539 784 443 162 783 728 407
# 191 54 425 240 639 530 842 965 148 63
# 321 11 111 390 808 482 601 543 984 823
# 600 388 63 508 683 159 150 695 91 324
# 301 72 160 330 342 731 799 388 371 117
# 289 327 510 901 724 172 796 844 803 138
# 250 15 438 590 805 21 432 591 756 633
# 918 306 492 721 592 775 174 302 194 268
