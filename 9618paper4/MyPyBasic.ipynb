# %% [markdown]
# # In A2 python, no internet connection and references are allowed
#
# # Comment of any variables is ##significant##
#
# # 1D and 2D array, declaration, common operation and algorithms
#
# # common opeations:
# i. basics: data types, vars, expression, program constucts
#
# ii. implement ADT by using arrays or with objects
#
# # recursion
#
# # searching
# i. linear search
#
# ii. binary search
#
# # sorting
# i. bubble sort
#
# ii. insertion sort
#
# # classes and objects

# %%
a = '她说："你好！"'
print(a)

b = "It's a good day."
print(b)

text = '''这是第一行
这是第二行
这是第三行''' #三引号可以在多行文字上使用
print(text)
# Out:
# 她说："你好！"
# It's a good day.
# 这是第一行
# 这是第二行
# 这是第三行

# %%
MyList=[]
for i in range(0,5):
        MyList.append(0)


print(MyList)
# Out:
# [0, 0, 0, 0, 0]

# %%
M = int(input("input your raw mark:"))

count = 0
while  count <= 10 :
    
    if M >= 120:
        print("合格")
    else:
        print("不合格")
    count += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 M = int(input("input your raw mark:"))
#       3 count = 0
#       4 while  count <= 10 :
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# variables, data types and expressions
# in python, variables can be used without declaration
# charachers can be used to a variable name 
# upper and lower letters, 0-9(number must not in the 1st place of the name)
intA = 10 # declare and initialise a variable, type of integer
intB = 20 
str1 = "abc"
print(type(intA))
print(type(str1))
# Out:
# <class 'int'>
# <class 'str'>

# %%
import random
wordNum = 0
for i in range (0, 10, 2): #FOR I <- 1 TO 10 STEP 2
    r = random.randint(3, 10)
    print("i=", i, "\t"+"r=", r) # Alt: srt(i) str(r), str(a) = NUM_TO_STR(a)
    if r >= 5:
        wordNum = 0
    else:
        wordNum +=1

print(wordNum)
# Out:
# i= 0 	r= 3
# i= 2 	r= 3
# i= 4 	r= 8
# i= 6 	r= 6
# i= 8 	r= 5
# 0
