# %%
class NewRecord:
    def __init__(self,key, Item1, Item2):
        self.Key = key
        self.Item1 = Item1
        self.Item2 = Item2
        
HashTable = [None for i in range(200)]
Spare = [None for i in range(100)]
